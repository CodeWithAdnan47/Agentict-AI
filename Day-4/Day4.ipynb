# %%
from google.colab import userdata
#userdata.get('secretName')
from google import genai

client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))
prompt = "Who is PM of India"
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=prompt,
)

print(response.text)
# Out:
# The current Prime Minister of India is **Narendra Modi**.
#
# He has been in office since May 2014 and is currently serving his third consecutive term, following the 2024 general elections.

# %% [markdown]
# 🎯 Student Task: Summarize Using Gemini
# You are provided with the following paragraph:
#
# 📝 Input Paragraph:
#
# Over the past decade, education has experienced a significant shift due to rapid advancements in technology. Online learning platforms like Coursera, edX, and Khan Academy have made high-quality education accessible to millions of students worldwide. Virtual classrooms now allow real-time interaction between teachers and learners, breaking down geographical barriers. Artificial intelligence is further enhancing the learning experience through personalized tutoring, automated grading, and adaptive content delivery based on student performance. This shift has empowered students to learn at their own pace, revisit lectures, and explore diverse topics beyond their curriculum. Mobile apps and gamified learning modules are keeping learners engaged in innovative ways. However, this digital transformation also introduces challenges. Not all students have equal access to stable internet, quality devices, or a quiet learning environment at home. Additionally, the lack of face-to-face interaction may lead to feelings of isolation and reduced motivation. As we embrace the future of education, balancing technology with human support and inclusivity remains critical.
#
# ✅ Your Task:
#
# Use Gemini to summarize the above paragraph into exactly 5 bullet points.
#
# The bullet points should be concise, clear, and informative.
#
# You may prompt Gemini like this:
#
# Summarize the following paragraph into 5 bullet points:
# <paste paragraph here>

# %%
from google.colab import userdata
#userdata.get('secretName')
from google import genai
client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))
para= "Over the past decade, education has experienced a significant shift due to rapid advancements in technology. Online learning platforms like Coursera, edX, and Khan Academy have made high-quality education accessible to millions of students worldwide. Virtual classrooms now allow real-time interaction between teachers and learners, breaking down geographical barriers. Artificial intelligence is further enhancing the learning experience through personalized tutoring, automated grading, and adaptive content delivery based on student performance. This shift has empowered students to learn at their own pace, revisit lectures, and explore diverse topics beyond their curriculum. Mobile apps and gamified learning modules are keeping learners engaged in innovative ways. However, this digital transformation also introduces challenges. Not all students have equal access to stable internet, quality devices, or a quiet learning environment at home. Additionally, the lack of face-to-face interaction may lead to feelings of isolation and reduced motivation. As we embrace the future of education, balancing technology with human support and inclusivity remains critical."
prompt = f"Summarize the following paragraph into 5 bullet points and the points should be more clean,clear and understandable:{para}"
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=prompt,
)
print(response.text)
# Out:
# Here is a clear and concise summary of the paragraph:
#
# *   **Global Accessibility:** Online platforms and virtual classrooms have removed geographical barriers, making high-quality education available to millions worldwide.
# *   **AI Integration:** Artificial intelligence is personalizing the learning experience through customized tutoring, adaptive content, and automated grading.
# *   **Flexibility and Engagement:** Modern tools like mobile apps and gamified modules allow students to learn at their own pace and stay motivated through interactive technology.
# *   **The Digital Divide:** A significant challenge remains regarding unequal access to stable internet, quality devices, and conducive learning environments.
# *   **Human-Tech Balance:** Future success depends on balancing technological innovation with human interaction and inclusivity to prevent student isolation.

# %%
from google.colab import userdata
#userdata.get('secretName')
from google import genai

client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))
memory=[]
while True:
  prompt= input("Enter Your Question: ")
  if prompt == "exit":
    print("Thank You!! Good Bye!!")
    break
  memory.append(f"User Input: {prompt}")

  response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=memory,
  )
  print(response.text)
  memory.append(f"LLM Response: {response.text}")
print(f"Your Chat: {memory}")
# Out:
# Enter Your Question: hi i am adnan
# Hi Adnan! It's nice to meet you. How can I help you today?
# Enter Your Question: who am i
# You are Adnan! You just introduced yourself to me a moment ago. How can I help you further, Adnan?
# Enter Your Question: exit
# Thank You!! Good Bye!!
# Your Chat: ['User Input: hi i am adnan', "LLM Response: Hi Adnan! It's nice to meet you. How can I help you today?", 'User Input: who am i', 'LLM Response: You are Adnan! You just introduced yourself to me a moment ago. How can I help you further, Adnan?']

# %% [markdown]
# Prompt Chaining : Topic -> Detailed Anylysis -> 5-line bullet summary

# %%
from google.colab import userdata
#userdata.get('secretName')
from google import genai
client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))
topic= input("Enter The Topic: ")
prompt=f"Make the Detailed Anaylis of {topic} and provide 5 lines bullet summary"
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=prompt,
)
print(response.text)
# Out:
# Enter The Topic: Football
# This detailed analysis explores football (soccer) as a global phenomenon, examining its structural appeal, economic impact, and tactical evolution.
#
# ---
#
# ### **Detailed Analysis of Football**
#
# #### **1. Structural Simplicity and Global Accessibility**
# The primary reason for football’s dominance is its low barrier to entry. Unlike sports that require expensive equipment (ice hockey) or specific infrastructure (tennis), football requires only a ball. This simplicity has allowed it to permeate every socio-economic layer of society, from the favelas of Brazil to the elite academies of Europe.
#
# #### **2. Tactical Evolution and "The Beautiful Game"**
# Football has transitioned from a physical test of strength to a high-speed "human chess" match.
# *   **The Early Era:** Focused on individual dribbling and direct long balls.
# *   **The Mid-20th Century:** The rise of "Total Football" (Netherlands), where players were interchangeable in positions.
# *   **The Modern Era:** Characterized by high-intensity pressing (Gegenpressing) and data-driven "Tiki-taka" (possession-based play). Coaches now use advanced metrics like xG (Expected Goals) to optimize performance.
#
# #### **3. Economic Powerhouse**
# Football is a multi-billion dollar industry. The European "Big Five" leagues (Premier League, La Liga, Bundesliga, Serie A, and Ligue 1) generate billions in broadcasting rights annually. The transfer market has become a high-stakes financial ecosystem, with top players commanding fees exceeding $100 million. This commercialization has turned clubs from local community assets into global corporate brands.
#
# #### **4. Technological Integration**
# The 21st century has seen football embrace technology to ensure fairness and enhance performance:
# *   **VAR (Video Assistant Referee):** Aimed at correcting "clear and obvious errors."
# *   **Goal-Line Technology:** Using high-speed cameras to determine if the ball crossed the line.
# *   **Wearable Tech:** GPS trackers and heart rate monitors allow staff to manage player fatigue and prevent injuries.
#
# #### **5. Cultural and Geopolitical Influence**
# The FIFA World Cup is the most-watched sporting event on Earth, often exceeding the Olympics in viewership. Football serves as a tool for "soft power," where nations use the sport to improve their global image. It has the unique power to stop civil wars (as seen in Ivory Coast in 2005) or ignite nationalistic fervor, making it more than just a game.
#
# ---
#
# ### **5-Line Bullet Summary**
#
# *   **Global Reach:** With over 3.5 billion fans, football is the world's most popular sport due to its minimal equipment requirements and simple rules.
# *   **Economic Impact:** It functions as a massive global industry, driven by multi-billion dollar broadcasting deals, sponsorships, and a high-stakes transfer market.
# *   **Tactical Sophistication:** The game has evolved from simple physical contests into a complex tactical sport relying on data analytics and fluid player roles.
# *   **Technological Shift:** The modern era is defined by the integration of VAR and goal-line technology to increase officiating accuracy and player performance tracking.
# *   **Social Unifier:** Beyond the pitch, football acts as a powerful cultural force that influences national identity, international diplomacy, and community development.
