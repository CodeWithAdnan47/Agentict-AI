# %% [markdown]
# Travel Itinerary Builder using LLM (PromptTemplate + Chain)
# Write a program that takes a user’s city, number of days, travel style (relaxed/busy), and interests as input, and uses Gemini (via LangChain) to generate a day-wise travel itinerary.
#
# You must use PromptTemplate to format the prompt and a basic LangChain chain to call Gemini.
#
# 📥 Sample Input
# City: Jaipur Days: 2 Travel Style: relaxed Interests: forts, local food, culture, shopping
#
# ⚠️ Important Rule
# You should NOT create the itinerary yourself.
#
# Instead, you must:
#
# collect inputs from the user,
# pass them to Gemini LLM using a properly formatted PromptTemplate,
# print the LLM’s response.
# ✅ Gemini LLM should do the following
# 1) Create a Day-wise plan
# Must generate the plan as:
#
# Day 1
# Day 2
# … up to the number of days entered by the user
# 2) Include time blocks for every day
# Each day must contain:
#
# Morning
# Afternoon
# Evening
# 3) Add one budget-saving tip per day
# At the end of each day, Gemini must add:
#
# ✅ Budget Tip: (one practical money-saving suggestion)
#
# ✅ Output Format Requirement (Strict)
# Gemini must return output exactly in this structure:
#
# Day 1
#
# Morning: ...
# Afternoon: ...
# Evening: ...
# Budget Tip: ...
# Day 2
#
# Morning: ...
# Afternoon: ...
# Evening: ...
# Budget Tip: ...
# (continue till all days)
#
# 🔧 Implementation Requirements (LangChain)
# Your Colab notebook must include:
#
# PromptTemplate for the prompt
# Gemini model connection (LangChain)
# a basic chain (LLMChain OR prompt | llm style)
# user input collection
# final response printed

# %%
# !pip install langchain langchain-google-genai
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-4.1.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.2.1)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<2.0.0,>=1.56.0 (from langchain-google-genai)
#   Downloading google_genai-1.56.0-py3-none-any.whl.metadata (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.3/53.3 kB 2.7 MB/s eta 0:00:00
# Collecting langchain-core<2.0.0,>=1.2.1 (from langchain)
#   Downloading langchain_core-1.2.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.12.0)
# Collecting google-auth<3.0.0,>=2.45.0 (from google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai)
#   Downloading google_auth-2.45.0-py2.py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.4.59)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.0)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.11)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.6.1)
# Downloading langchain_google_genai-4.1.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 5.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_genai-1.56.0-py3-none-any.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.6/426.6 kB 13.3 MB/s eta 0:00:00
# Downloading langchain_core-1.2.6-py3-none-any.whl (489 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.1/489.1 kB 35.1 MB/s eta 0:00:00
# Downloading google_auth-2.45.0-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 19.5 MB/s eta 0:00:00
# Installing collected packages: filetype, google-auth, langchain-core, google-genai, langchain-google-genai
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.43.0
#     Uninstalling google-auth-2.43.0:
#       Successfully uninstalled google-auth-2.43.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.1
#     Uninstalling langchain-core-1.2.1:
#       Successfully uninstalled langchain-core-1.2.1
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.55.0
#     Uninstalling google-genai-1.55.0:
#       Successfully uninstalled google-genai-1.55.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.43.0, but you have google-auth 2.45.0 which is incompatible.
# Successfully installed filetype-1.2.0 google-auth-2.45.0 google-genai-1.56.0 langchain-core-1.2.6 langchain-google-genai-4.1.2

# %%
from langchain_core.runnables import chain
from langchain_google_genai import ChatGoogleGenerativeAI
from google.colab import userdata
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite",google_api_key=userdata.get('GEMINI_API_KEY'))
city = input("Enter Name of The Citt: ")
no_days = int(input("Enter Number of Days: "))
travel_style = input("Enter Your Travel Style (Relaxed/Busy): ")
interests = input("Enter Your Interests: ")
prompt = PromptTemplate(input_variables=["city","no_days","travel_style","interests"],
        template="""
        1.Create a Day-Wise Travel Itinerary for {city} upto the {no_days}
        Consider Travel Style: {travel_style}
        Consider Interests: {interests}
        2. Include Time Block for Each day(Morning,Afternoon,Evening)
        3. Add Budget-Saving(Practical Money-Saving) Tip for Each Day

        """)
chain = prompt | llm | StrOutputParser()
respone = chain.invoke({"city":city,"no_days":no_days,"travel_style":travel_style,"interests":interests})
print("--------------------------TRAVELL ITINERARY----------------------------------")
print(respone)
print("----------------------------------------------------------------------------")
# Out:
# Enter Name of The Citt: Jaipur
# Enter Number of Days: 2
# Enter Your Travel Style (Relaxed/Busy): relaxed
# Enter Your Interests: forts, local food, culture, shopping
# --------------------------TRAVELL ITINERARY----------------------------------
# ## Jaipur: A Relaxed Exploration of Forts, Flavors, Culture, and Shopping (2 Days)
#
# This itinerary is designed for a relaxed pace, allowing you to soak in the essence of Jaipur without feeling rushed. We've balanced iconic landmarks with local experiences and plenty of opportunities to indulge in delicious food and vibrant shopping.
#
# ---
#
# ### Day 1: Majestic Forts & Royal Heritage
#
# **Travel Style:** Relaxed, soaking in the grandeur and history.
# **Interests:** Forts, Culture, Local Food.
#
# **Morning (9:00 AM - 1:00 PM): Amber Fort - A Royal Spectacle**
#
# *   **9:00 AM - 10:00 AM:** Begin your day with a leisurely breakfast at your hotel or a local cafe.
# *   **10:00 AM - 1:00 PM:** Head to the magnificent **Amber Fort (Amer Fort)**, located about 11 km from the city center. Take your time exploring its sprawling complex, admiring the intricate architecture, and learning about the Rajput royalty. Don't miss the Diwan-e-Aam, Diwan-e-Khas, Sheesh Mahal (Mirror Palace), and the stunning views of Maota Lake.
#     *   **Transport:** Consider a pre-booked taxi or an auto-rickshaw for a comfortable and direct ride. If you're feeling adventurous, you can opt for a shared taxi or even a local bus for a more budget-friendly option.
#     *   **Budget-Saving Tip:** **Purchase your tickets online in advance.** This often offers a slight discount and saves you time queuing at the ticket counter, especially during peak season. Also, consider sharing a taxi with other travelers if possible to split the cost.
#
# **Lunch (1:00 PM - 2:30 PM): Local Flavors near Amber**
#
# *   **1:00 PM - 2:30 PM:** Enjoy a traditional Rajasthani lunch at a local restaurant near Amber Fort. Look for places that serve thalis for a comprehensive taste of local dishes.
#     *   **Budget-Saving Tip:** **Opt for a "Thali" meal.** This is a platter with a variety of dishes, offering great value for money and allowing you to sample multiple flavors at a fixed price. Avoid tourist-trap restaurants directly at the fort entrance.
#
# **Afternoon (2:30 PM - 5:30 PM): City Palace & Jantar Mantar - Royal Living & Astronomical Wonders**
#
# *   **2:30 PM - 3:00 PM:** Travel back to the city center to visit the **City Palace**. This grand complex houses museums, courtyards, and royal residences. Explore the Mubarak Mahal, Chandra Mahal, and the beautiful Peacock Gate.
# *   **4:00 PM - 5:30 PM:** Adjacent to the City Palace is **Jantar Mantar**, an astronomical observatory with colossal instruments built by Maharaja Jai Singh II. It's a fascinating glimpse into ancient Indian scientific prowess.
#     *   **Budget-Saving Tip:** **Combine your tickets if possible.** Sometimes, there are combo tickets available for the City Palace and Jantar Mantar, offering a slight saving. Walk between these two attractions as they are in close proximity.
#
# **Evening (5:30 PM onwards): Bazaars & Dinner - Shopping & Culinary Delights**
#
# *   **5:30 PM - 8:00 PM:** Immerse yourself in the vibrant **Johari Bazaar** (for jewelry and gemstones) and **Bapu Bazaar** (for textiles, handicrafts, and local souvenirs). Enjoy a leisurely stroll, browse through the colorful stalls, and practice your bargaining skills.
# *   **8:00 PM onwards:** Savor a delicious dinner at a restaurant of your choice. Consider trying some iconic Jaipur street food or a more upscale dining experience.
#     *   **Budget-Saving Tip:** **Practice polite bargaining in the bazaars.** Start at around 50-60% of the quoted price and negotiate upwards. For dinner, explore local eateries away from the main tourist drag for more authentic and affordable meals. Try popular spots for **Laal Maas** (spicy red mutton curry) or **Dal Baati Churma**.
#
# ---
#
# ### Day 2: Iconic Landmarks, Cultural Immersion & Sweet Endings
#
# **Travel Style:** Relaxed, exploring iconic sights and experiencing local culture.
# **Interests:** Forts, Local Food, Culture, Shopping.
#
# **Morning (9:30 AM - 1:00 PM): Hawa Mahal & Nahargarh Fort - Iconic Facade & Panoramic Views**
#
# *   **9:30 AM - 10:30 AM:** Begin your day with a relaxed breakfast.
# *   **10:30 AM - 11:30 AM:** Visit the iconic **Hawa Mahal (Palace of Winds)**. Admire its unique facade from the outside and understand its purpose. You can also go inside to explore its levels and enjoy the views.
#     *   **Budget-Saving Tip:** You don't need to spend a lot of time inside Hawa Mahal to appreciate its architectural marvel. Taking photos from the street and perhaps going up to the first few levels is often sufficient for many.
# *   **11:30 AM - 1:00 PM:** Head to **Nahargarh Fort**. Perched on the Aravalli hills, it offers breathtaking panoramic views of Jaipur city. Explore the Madhavendra Bhawan, a beautiful royal suite within the fort.
#     *   **Transport:** An auto-rickshaw or taxi is recommended to reach Nahargarh Fort due to its elevated location.
#     *   **Budget-Saving Tip:** **Pack your own water and snacks.** While there are vendors at Nahargarh Fort, prices can be inflated. Enjoy the views and the refreshing breeze.
#
# **Lunch (1:00 PM - 2:30 PM): Local Eateries near the City Center**
#
# *   **1:00 PM - 2:30 PM:** Return to the city and find a local eatery for lunch. Explore areas like C-Scheme or Sardar Market for a variety of dining options.
#     *   **Budget-Saving Tip:** Seek out small, family-run restaurants for authentic and affordable meals. Look for places packed with locals – it's usually a good sign of quality and value.
#
# **Afternoon (2:30 PM - 5:30 PM): Albert Hall Museum & Artisanal Crafts**
#
# *   **2:30 PM - 4:00 PM:** Visit the **Albert Hall Museum**, Jaipur's oldest museum. It houses a diverse collection of artifacts, including pottery, paintings, textiles, and sculptures, showcasing the rich heritage of Rajasthan.
#     *   **Budget-Saving Tip:** Check if you have a **Jaipur Museum Pass** if you plan to visit multiple museums. This can offer savings.
# *   **4:00 PM - 5:30 PM:** Explore the **Tripolia Bazaar** and its adjoining lanes, known for traditional Rajasthani handicrafts, blue pottery, and lac bangles. You can also visit a **Block Printing workshop** if you're interested in learning about this art form.
#     *   **Budget-Saving Tip:** Instead of buying directly from shops, consider visiting a **government-approved emporium** for fixed prices and guaranteed authenticity, or **explore smaller workshops** where you might get a better deal directly from the artisans (with respectful bargaining).
#
# **Evening (5:30 PM onwards): Pink City Delights & Farewell Dinner**
#
# *   **5:30 PM - 7:00 PM:** Take a leisurely stroll around the **Pink City** and re-visit any markets you particularly enjoyed or explore the charming lanes.
# *   **7:00 PM onwards:** Enjoy a farewell dinner. Consider trying some popular Rajasthani sweets like **Ghewar** or **Mawa Kachori**.
#     *   **Budget-Saving Tip:** **Enjoy a "Chai" break** at a local tea stall in the evening. It's a delightful and inexpensive way to experience local life. For dinner, consider a rooftop restaurant for great views without necessarily breaking the bank, or revisit a favorite local spot from Day 1.
#
# ---
#
# **General Budget-Saving Tips for Jaipur:**
#
# *   **Stay in Budget-Friendly Accommodation:** Consider guesthouses or budget hotels in areas like Bani Park or near the railway station for more affordable options.
# *   **Utilize Public Transport:** Auto-rickshaws and local buses are cost-effective for getting around the city, especially for shorter distances. Negotiate fares before starting your journey with auto-rickshaws.
# *   **Drink Filtered Water:** Always carry a reusable water bottle and refill it with filtered water from reliable sources to save money and reduce plastic waste.
# *   **Eat Local:** Embrace street food and local eateries for delicious and budget-friendly meals.
# *   **Haggling is Expected:** In most bazaars, prices are not fixed. Be polite but firm when negotiating.
# *   **Carry Small Change:** Having small denominations of currency will make transactions easier, especially with street vendors and auto-rickshaws.
# *   **Consider Walking:** For attractions within close proximity, walking is a great way to save money and discover hidden gems.
# *   **Be Mindful of Tourist Traps:** Be wary of overly pushy touts and overly priced souvenir shops directly outside major attractions.
#
# **Enjoy your relaxed and enriching exploration of Jaipur!**
# ----------------------------------------------------------------------------
